# %%
import random
import os


listWords1 = ['chair', 'desktop','laptop','pencil','motorbike','car','cellphone','guitar']
listWords2 = ['dog', 'tiger','cat','bird','shark','lion','zebra','unicorn']
guessWord = []
inputLetter = ('abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ')
letter_storage = []


def firstMenu():
    print ('Welcome to Hangman game, writen by Omegaaaaaaaaaa! ')
    name = input('please input your name: ')
    if name == '':
        print ('Welcome noname player!')
    else:
        print ('Welcome ' + name)

def choiceMenu():
    while True:
        print('Now choose which way do you want to play: ')
        print('1: one player')
        print('2: two players')
        choice = int(input())
        if choice == 1:
            onePlayer()
            break
        elif choice == 2:
            print('this is the game for 2 players!')
            twoPlayers()
            break
        else:
            print('please input 1 or 2')
            continue
            
def onePlayer():
    print('You can only enter 1 letter each time from a-z')
    print('This is the game for 1 player!')
    print('Please choose type of the word: ')
    print('1: Object')
    print('2: Animal')
    while True:
        difChose = int(input('Your choice: '))
        if difChose == 1:
            secretWord = random.choice(listWords1)
            lenghWord = len(secretWord)
            print('The word you will input have ', lenghWord, ' letters')
            for character in secretWord:
                guessWord.append('-')
            print (guessWord)
            
            
            while True:
                guessLeft = int(input('please input how many times do you want to guess: '))
                if guessLeft == 1:
                    print('That is very risky! good luck')
                    break
                elif guessLeft == 0:
                    print('You must input number more than 0!')
                    continue
                else:
                    print('Have fun!')
                    break
            while guessLeft >0:
                guess = input('enter a letter: ').lower()
                if guess not in inputLetter:
                    print('You can only input 1 letter from a-z')
                elif guess in letter_storage:
                    print('You have already inputted this letter')
                else:
                    letter_storage.append(guess)
                    if guess in secretWord:
                        print('Correct!')
                        for x in range (0,lenghWord):
                            if secretWord[x] == guess:
                                guessWord[x] = guess
                                print (guessWord)
                        if '-' not in guessWord:
                            print ('You win the game, thank you for playing')
                            break
                    else:
                        print('This letter in not in the word, try again!')
                        guessLeft -= 1
                        print ('You only have ', guessLeft, ' guess left')
                        if guessLeft == 0:
                            print("Your are out you guess! The word was: ", secretWord)
            break 
        elif difChose == 2:
            secretWord = random.choice(listWords2)
            lenghWord = len(secretWord)
            print ('The word you will input have ', lenghWord, ' letters')
            for character in secretWord:
                guessWord.append('-')
            print (guessWord)
            
            while True:
                guessLeft = int(input('please input how many times do you want to guess: '))
                if guessLeft == 1:
                    print('That is very risky! good luck')
                    break
                elif guessLeft == 0:
                    print('You must input number more than 0!')
                    continue
                else:
                    print('Have fun!')  
                    break
            while guessLeft >0:
                guess = input('enter a letter: ').lower()
                if guess not in inputLetter:
                    print('You can only input 1 letter from a-z')
                elif guess in letter_storage:
                    print('You have already inputted this letter')
                else:
                    letter_storage.append(guess)
                    if guess in secretWord:
                        print('Correct!')
                        for x in range (0,lenghWord):
                            if secretWord[x] == guess:
                                guessWord[x] = guess
                                print (guessWord)
                        if '-' not in guessWord:
                            print ('You win the game, thank you for playing')
                            break
                    else:
                        print('This letter in not in the word, try again!')
                        guessLeft -= 1
                        print ('You only have ', guessLeft, ' guess left')
                        if guessLeft == 0:
                            print("Your are out you guess! The word was: ", secretWord)
           
            break
        else:
            print('Please input 1 or 2')
            continue
   
        
def twoPlayers():
    print('Please input the definition: ')
    definition = input('input: ')
    secretWord = input('Please enter the secret word: ')
    lenghWord = len(secretWord)
    print ('* \n'  *50)
    os.system('clear')

    print('The word you will input have ', lenghWord, ' letters')
    print ('Here is your definition: ' , definition)
    for character in secretWord:
        guessWord.append('-')
    print (guessWord)
    
    while True:
        guessLeft = int(input('please input how many times do you want to guess: '))
        if guessLeft == 1:
            print('That is very risky! good luck')
            break
        elif guessLeft == 0:
            print('You must input number more than 0!')
            continue
        else:
            print('Have fun!')
            break
    while guessLeft >0:
        guess = input('enter a letter: ').lower()
        if guess not in inputLetter:
            print('You can only input 1 letter from a-z')
        elif guess in letter_storage:
            print('You have already inputted this letter')
        else:
            letter_storage.append(guess)
            if guess in secretWord:
                print('Correct!')
                for x in range (0,lenghWord):
                    if secretWord[x] == guess:
                        guessWord[x] = guess
                        print (guessWord)
                if '-' not in guessWord:
                    print ('You win the game, thank you for playing')
                    break
            else:
                print('This letter in not in the word, try again!')
                guessLeft -= 1
                if guessLeft == 0:
                    print("Your are out you guess! The word was: ", secretWord)
                else:
                    print ('You only have ', guessLeft, ' guess left')


firstMenu()                
choiceMenu()
# Out:
# Welcome to Hangman game, writen by Omegaaaaaaaaaa!
# please input your name: Giang
# Welcome Giang
# Now choose which way do you want to play:
# 1: one player
# 2: two players
# 1
# You can only enter 1 letter each time from a-z
# This is the game for 1 player!
# Please choose type of the word:
# 1: Object
# 2: Animal
# Your choice: 2
# The word you will input have  7  letters
# ['-', '-', '-', '-', '-', '-', '-']
# please input how many times do you want to guess: 9
# Have fun!
# enter a letter: H
# This letter in not in the word, try again!
# You only have  8  guess left
# enter a letter: l
# This letter in not in the word, try again!
# You only have  7  guess left
# enter a letter: o
# Correct!
# ['-', '-', '-', '-', 'o', '-', '-']
# enter a letter: p
# This letter in not in the word, try again!
# You only have  6  guess left
# enter a letter: z
# This letter in not in the word, try again!
# You only have  5  guess left
# enter a letter: n
# Correct!
# ...
